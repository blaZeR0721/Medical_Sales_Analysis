# %% [markdown]
# # Medicine Sales Analysis
#
# Explores daily revenue and quantity trends, hourly sales patterns,
# and a day-hour heatmap derived from pharmacy transaction data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------------------------------------------------------------------
# Constants
# ---------------------------------------------------------------------------

DATA_PATH = r"D:\7th sem\project\Medical_Sales_Analysis\data\pharmacy_sales.csv"
DATE_FORMAT = "%d-%m-%Y %H:%M"
WEEKDAY_ORDER = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# ---------------------------------------------------------------------------
# Data loading
# ---------------------------------------------------------------------------

df = pd.read_csv(DATA_PATH)
df["DateTime"] = pd.to_datetime(df["DateTime"], format=DATE_FORMAT, errors="coerce")
df["Date"] = df["DateTime"].dt.date
df["Day"] = df["DateTime"].dt.day_name()
df["Hour"] = df["DateTime"].dt.hour

df.head()
# Out:
#      SaleID            DateTime DrugID       DrugName     DrugClass  Price  \
# 0  12005226 2023-04-01 09:04:00  D0051  Ciprofloxacin  Psychotropic    106
# 1  12005226 2023-04-01 09:04:00  D0051     Olmesartan     Analgesic    170
# 2  12005227 2023-04-01 09:05:00  D0049      Donepezil     Antiviral    184
# 3  12005227 2023-04-01 09:05:00  D0061   Fexofenadine      Hormonal     54
# 4  12005227 2023-04-01 09:05:00  D0034       Naproxen   Respiratory     50
#
#    ExpDate  Quantity  TotalSales        Date       Day  Hour
# 0  2024-03         6         636  2023-04-01  Saturday     9
# 1  2023-10         2         340  2023-04-01  Saturday     9
# 2  2024-03         5         920  2023-04-01  Saturday     9
# 3  2023-05         6         324  2023-04-01  Saturday     9
# 4  2024-01         3         150  2023-04-01  Saturday     9

# %% [markdown]
# ## Daily Revenue Trend
#
# Total sales revenue aggregated by calendar date.

# %%
daily_sales = df.groupby("Date")["TotalSales"].sum().reset_index()

fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(data=daily_sales, x="Date", y="TotalSales", marker="o", ax=ax)
ax.set_title("Daily Total Medicine Sales Trend")
ax.set_xlabel("Date")
ax.set_ylabel("Total Sales (₹)")
ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Observed Trends
#
# - Daily revenue is broadly stable, ranging from ₹950,000 to ₹1,050,000.
# - Revenue peaked on April 6 (highest) and April 11 (second-highest).
# - A sharp decline occurred on April 13.
#
# ### Suggestions
#
# - Ensure adequate stock and staffing on historically high-revenue days.
# - Consider targeted promotions on stable days to sustain demand.
#
# ### Limitations
#
# - Trend reflects revenue, not quantity sold.
# - External factors (holidays, promotions, doctor availability) are not captured.

# %% [markdown]
# ## Daily Quantity Trend
#
# Total units sold aggregated by calendar date.

# %%
daily_quantity = df.groupby("Date")["Quantity"].sum().reset_index()

fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(data=daily_quantity, x="Date", y="Quantity", marker="s", ax=ax)
ax.set_title("Daily Quantity of Medicines Sold")
ax.set_xlabel("Date")
ax.set_ylabel("Total Quantity Sold")
ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Observed Trends
#
# - Daily quantity remained mostly stable between 8,400 and 9,100 units.
# - Quantity peaked on April 6 and April 11, consistent with the revenue peaks.
# - April 13 saw a significant drop to below 5,000 units.
#
# ### Suggestions
#
# - Use stable quantity trends to plan weekly stock orders and shelf allocation.
# - Ensure adequate inventory and staffing on historically high-demand days.
#
# ### Limitations
#
# - Reflects quantity only; profitability is not captured.
# - No segmentation by drug category or medicine type.

# %% [markdown]
# ## Revenue vs Quantity Correlation
#
# Scatter plot comparing daily quantity sold against daily revenue to assess correlation.

# %%
daily_summary = df.groupby("Date")[["TotalSales", "Quantity"]].sum().reset_index()

fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=daily_summary, x="Quantity", y="TotalSales", ax=ax)
ax.set_title("Relationship Between Daily Quantity Sold and Revenue")
ax.set_xlabel("Total Quantity Sold (per day)")
ax.set_ylabel("Total Sales (₹) per day")
ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Observed Trends
#
# - Strong positive correlation: higher quantity sold consistently maps to higher revenue.
# - Most days cluster between 8,400–9,100 units and ₹950,000+ in revenue.
# - April 13 is a clear outlier — low on both quantity and revenue.
#
# ### Suggestions
#
# - Increasing sales volume is an effective lever for revenue growth.
#
# ### Limitations
#
# - External factors (holidays, supplier delays) affecting both metrics are not accounted for.

# %% [markdown]
# ## Hourly Sales Pattern
#
# Total revenue distributed across hours of the day.

# %%
hourly_sales = df.groupby("Hour")["TotalSales"].sum().reset_index()

fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(hourly_sales["Hour"], hourly_sales["TotalSales"], marker="o")
ax.set_title("Hourly Sales Pattern")
ax.set_xlabel("Hour of Day")
ax.set_ylabel("Total Sales (₹)")
ax.set_xticks(range(9, 18))
ax.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Observed Trends
#
# - Sales rise from 10 AM, peak between 11 AM and 1 PM, then gradually decline.
# - A stable plateau is observed from 3 PM to 4 PM.
#
# ### Suggestions
#
# - Align staffing and operations with peak sales hours (11 AM–1 PM).
# - Use off-peak hours for restocking and administrative tasks.
#
# ### Limitations
#
# - Reflects total revenue, not transaction count or footfall.
# - Weekends, holidays, and weather may shift these patterns.

# %% [markdown]
# ## Day-Hour Sales Heatmap
#
# Revenue distribution across days of the week and hours of the day.

# %%
heatmap_data = (
    df.pivot_table(
        index="Day",
        columns="Hour",
        values="TotalSales",
        aggfunc="sum",
        fill_value=0,
    )
    .reindex(WEEKDAY_ORDER)
)

fig, ax = plt.subplots(figsize=(14, 6))
sns.heatmap(heatmap_data, cmap="YlGnBu", linewidths=0.5, ax=ax)
ax.set_title("Sales Heatmap by Day and Hour")
ax.set_xlabel("Hour of Day")
ax.set_ylabel("Day of Week")
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Observed Trends
#
# - Peak activity occurs Monday to Wednesday between 10 AM and 2 PM.
# - Friday shows the lowest activity, particularly after 2 PM.
# - Saturday 3 PM and Sunday 4 PM are notable weekend spikes.
#
# ### Suggestions
#
# - Increase staffing during weekday peaks (10 AM–2 PM) and Saturday 3 PM.
# - Reduce inventory orders and staffing on Fridays to cut costs.
#
# ### Limitations
#
# - High revenue may reflect price, not customer volume.
# - Holidays and local events are not reflected in this view.
